# %%
from pylabel import importer

# %%
dataset = importer.ImportYoloV5(path="D:/Files/Projects/Engineering Drawing Object Detection/data/combined_data/labels/train/", path_to_images="D:/Files/Projects/Engineering Drawing Object Detection/data/combined_data/images/train/",
                                cat_names=['bar-scale', 'color-stamp', 'detail-labels', 'north-sign'], name="data")
dataset
# Out:
# Importing YOLO files...: 100%|██████████| 144/144 [00:00<00:00, 198.78it/s]

# %%
train_data = dataset.df

# %%
train_data
# Out:
#                                             img_folder  \
# id
# 0    D:/Files/Projects/Engineering Drawing Object D...
# 1    D:/Files/Projects/Engineering Drawing Object D...
# 2    D:/Files/Projects/Engineering Drawing Object D...
# 3    D:/Files/Projects/Engineering Drawing Object D...
# 4    D:/Files/Projects/Engineering Drawing Object D...
# ..                                                 ...
# 894  D:/Files/Projects/Engineering Drawing Object D...
# 895  D:/Files/Projects/Engineering Drawing Object D...
# 896  D:/Files/Projects/Engineering Drawing Object D...
# 897  D:/Files/Projects/Engineering Drawing Object D...
# 898  D:/Files/Projects/Engineering Drawing Object D...
#
#                      img_filename img_path  img_id  img_width  img_height  \
# id
# 0    009bb197-output_folder77.png                0        792         612
# 1    009bb197-output_folder77.png                0        792         612
# ...

# %%
train_data.columns
# Out:
# Index(['img_folder', 'img_filename', 'img_path', 'img_id', 'img_width',
#        'img_height', 'img_depth', 'ann_segmented', 'ann_bbox_xmin',
#        'ann_bbox_ymin', 'ann_bbox_xmax', 'ann_bbox_ymax', 'ann_bbox_width',
#        'ann_bbox_height', 'ann_area', 'ann_segmentation', 'ann_iscrowd',
#        'ann_keypoints', 'ann_pose', 'ann_truncated', 'ann_difficult', 'cat_id',
#        'cat_name', 'cat_supercategory', 'split', 'annotated'],
#       dtype='object')

# %%
train_data.groupby('img_filename')[['img_id', 'img_width', 'img_height', 'cat_id']].agg(list).reset_index()
# Out:
#                      img_filename                               img_id  \
# 0    009bb197-output_folder77.png                   [0, 0, 0, 0, 0, 0]
# 1    02cd7804-output_folder56.png                         [1, 1, 1, 1]
# 2         04849a42-outfile153.png                [2, 2, 2, 2, 2, 2, 2]
# 3         0571ef54-outfile109.png             [3, 3, 3, 3, 3, 3, 3, 3]
# 4         063cfe03-outfile151.png             [4, 4, 4, 4, 4, 4, 4, 4]
# ..                            ...                                  ...
# 139     f9725cc8-image_page16.png       [139, 139, 139, 139, 139, 139]
# 140       fae5fc59-outfile115.png       [140, 140, 140, 140, 140, 140]
# 141       fcd497aa-outfile140.png  [141, 141, 141, 141, 141, 141, 141]
# 142       fd9c4878-outfile112.png  [142, 142, 142, 142, 142, 142, 142]
# 143  fe1da71c-output_folder52.png            [143, 143, 143, 143, 143]
#
#                                             img_width  \
# 0                      [792, 792, 792, 792, 792, 792]
# ...
